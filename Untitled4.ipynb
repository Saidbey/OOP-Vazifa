# %% [markdown]
# <a href="https://colab.research.google.com/github/Saidbey/OOP-Vazifa/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Oson1:
    def __init__(self, a):
        self.a = a

    def output_a(self):
        print(self.a)


class Oson2:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def summa(self):
        print(self.a + self.b)


class Oson3:
    def __init__(self, a):
        self.a = a

    def plus_minus(self):
        if self.a >= 0:
            print('Musbat')
        else:
            print('Manfiy')

class Oson4:
    def __init__(self, a):
        self.a = a

    def odd_even(self):
        if self.a == self.a % 2:
            print('Number is an even number')
        else:
            print('Number is an odd number')

class Oson5:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def daraja(self):
        print(self.a ** self.b)

class MyClass8:
    def __init__(self):
        self.numbers = []

    def compare_lists(self, new_list):
        if sum(new_list) > sum(self.numbers):
        print(new_list)
        else:
        print(self.numbers)


class Myclass10:
    def __init__(self):
        self.numbers = []

    def devide(self, d):
        result = []
        for k in self.numbers:
            if k%d ==0:
                result.append(k)
        return result

class Texnika():
    def __init__(self, brand, model, type):
        self.brand = brand
        self.model = model
        self.type = type
    def info(self):
        print(f"Brand:{self.brand}, Model:{self.model},Type:{self.type}")

class Notebooks(Texnika):
    def __init__(self,brand, model, type, video_card, ram, display):
        super().__init__(brand, model, type)
        self.video_card = video_card
        self.ram = ram
        self.display = display
    def more_info(self):
        info = f"Brand:{self.brand}, Model:{self.model},Type:{self.type}"
        info += f"Video kartasi:{self.video_card},ram:{self.ram},display:{self.display}"
        print(info)

class Televisions(Texnika):
    def __init__(self, brand, model, type, size, display):
        super().__init__(brand, model, type)
        self.size = size
        self.display = display
    def more_info(self):
        info = f"Brand:{self.brand}, Model:{self.model},Type:{self.type},"
        info += f"display:{self.display},size:{self.size}"
        return info

class Smartphones(Texnika):
    def __init__(self, brand, model, type, size, sim_count):
        super().__init__(brand, model, type)
        self.size = size
        self.sim_count = sim_count
    def more_info(self):
        info = f"Brand:{self.brand}, Model:{self.model},Type:{self.type},"
        info += f"size:{self.size},sim_count:{self.sim_count}"
        return info


class Transport():
    def __init__(self, brand, model, type):
        self.brand = brand
        self.model = model
        self.type = type
    def info(self):
        info = f"Brand:{self.brand},Model:{self.model},type:{self.type}"
        print(info)

class ElentroCars(Transport):
    def __init__(self, brand, model, type, battery_life, chargin_time):
        super().__init__(brand, model, type)
        self.battery_life = battery_life
        self.chargin_time = chargin_time
  
    def more_info(self):
        info = f"Brand:{self.brand},Model:{self.model},type:{self.type}"
        info += f"Battery_life:{self.battery_life},CHargin_time:{self.chargin_time}"
        return info


class Sportcars(Transport):
    def __init__(self,brand, model, type, motor, color):
        super().__init__(brand, model, type)
        self.motor = motor
        self.color = color
    def more_info(self):
        info = f"Brand:{self.brand},Model:{self.model},type:{self.type}"
        info += f"Motor:{self.motor},Rangi:{self.color}"
        return info

class Truck(Sportcars):
    def __init__(self, brand, model, type, height, long, wiegh):
        super().__init__(brand, model, type)
        self.height = height
        self.long = long
        self.weigh = wiegh
    def more_info(self):
        info = f"Brand:{self.brand},Model:{self.model},type:{self.type}"
        info += f"uzunligi:{self.long},og'irligi:{self.weigh},boyi:{self.height}"
        return info
